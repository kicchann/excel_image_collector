# %%
import re
import os
import io
from typing import *
from dataclasses import dataclass
from PIL import Image
from zipfile import ZipFile
import xml.etree.ElementTree as ET

fpath = '***'

# %%
@dataclass(frozen=True)
class ImageData():
    sheet_code_name: str
    id_: str
    row: int
    col: int
    file_name: str


class ImageCollector():
    def __init__(self, file_path):
        self.__file_path:str = file_path
        self.__sheet_file_names = self.__get_sheet_file_names()

    def save_images(self) -> None:
        os.makedirs('./images', exist_ok=True)
        with ZipFile(fpath, 'r') as zip_data:
            for file in zip_data.namelist():
                if 'xl/media/image' in file:
                    file_data = zip_data.read(file)
                    # 画像のバイナリデータを読み込む
                    img_bin = io.BytesIO(file_data)
                    # バイナリデータをpillowから開く
                    img = Image.open(img_bin)
                    img.save((os.path.join('./images',os.path.basename(file))),quality = 95)
        return
    
    def collect_image_data(self) -> List[ImageData]:
        images: List[ImageData] = []
 
        for sheet_file_name in self.__sheet_file_names:
            drawing_id = self.__get_drawing_id_from_sheet_xml(sheet_file_name)
            if drawing_id is None:
                print(f'{sheet_file_name} has no drawings')
                continue
            drawing_file_name = self.__get_drawing_file_name_from_sheet_xml_rels(sheet_file_name, drawing_id)
            image_infos = self.__get_image_infos_from_drawing_xml(drawing_file_name)
            if len(image_infos) == 0:
                print(f'{sheet_file_name} has no images')
                continue
            print(f'{sheet_file_name} has {len(image_infos)} images')
            image_paths = self.__get_image_paths_from_drawing_xml_rel(drawing_file_name)
            for image_info in image_infos:
                image_data = ImageData(
                    sheet_code_name=self.__get_code_name_in_sheet_xml(sheet_file_name),
                    id_=image_info['id'],
                    row=image_info['row'],
                    col=image_info['col'],
                    file_name=os.path.basename(image_paths[image_info['id']]))
                images += [image_data]

        return images

    def __get_xml(self, file_path_in_zip: str) -> ET.XML:
        # zipファイルから，指定したxmlファイルを取得
        with ZipFile(self.__file_path, 'r') as zip_data:
            file_data = zip_data.read(file_path_in_zip)
        return ET.XML(file_data)

    def __get_sheet_file_names(self) -> List[str]:
        # ZipFileを展開して，'xl/worksheets'以下のファイル名を取得
        with ZipFile(fpath, 'r') as zip_data:
            file_names = zip_data.namelist()
        l = [os.path.basename(file_name) for file_name in file_names 
                if file_name.startswith('xl/worksheets') and 
                    file_name.endswith('.xml')]
        return sorted(l, key=lambda s: int(re.search(r'\d+', s).group()))

    def __get_code_name_in_sheet_xml(self, sheet_file_name: str) -> str:
        # sheet.xmlから，codeNameを取得
        sheet_xml = self.__get_xml(f'xl/worksheets/{sheet_file_name}')
        return sheet_xml.find("{*}sheetPr").attrib["codeName"]

    def __get_drawing_id_from_sheet_xml(self, sheet_file_name: str) -> str:
        # sheet.xmlから，drawing.xmlのidを取得
        sheet_xml = self.__get_xml(f'xl/worksheets/{sheet_file_name}')
        try:
            return list(sheet_xml.find('{*}drawing').attrib.values())[0]
        except:
            return None

    def __get_drawing_file_name_from_sheet_xml_rels(self, sheet_file_name: str, drawing_id:str) -> str:
        # drawing idを使って，drawing_xml_pathを取得
        sheet_xml_relation = self.__get_xml(f'xl/worksheets/_rels/{sheet_file_name}.rels')
        for child in sheet_xml_relation:
            if child.attrib['Id'] == drawing_id:
                draw_xml_path = child.attrib['Target']
                break
        return os.path.basename(draw_xml_path)

    def __get_image_infos_from_drawing_xml(self, drawing_file_name: str) -> List:
        # drawing.xmlから，画像のidと位置情報を取得
        drawing_xml = self.__get_xml(f'xl/drawings/{drawing_file_name}')
        image_info_list = []
        for child in drawing_xml.findall('{*}twoCellAnchor'):
            image_dict = {}
            if child.find('{*}pic') == None:
                continue
            id_dict = child.find('{*}pic').find('{*}blipFill').find('{*}blip').attrib
            image_dict['id'] = list(id_dict.values())[0]
            image_dict['row'] = child.find('{*}from').find('{*}row').text
            image_dict['col'] = child.find('{*}from').find('{*}col').text
            image_info_list.append(image_dict)
        return image_info_list

    def __get_image_paths_from_drawing_xml_rel(self, drawing_file_name:str) -> Dict:
        # 画像のidから，画像のpathを取得
        drawing_xml_relation = self.__get_xml(f'xl/drawings/_rels/{drawing_file_name}.rels')
        image_paths = {}
        for child2 in drawing_xml_relation:
            image_paths[child2.attrib['Id']] = child2.attrib['Target'] # path
        return image_paths

# %%
collector = ImageCollector(fpath)
image_data_list = collector.collect_image_data()
for image_data in image_data_list:
    print(image_data.__dict__)
# Out:
# sheet1.xml has no drawings
# sheet2.xml has no drawings
# sheet3.xml has no drawings
# sheet4.xml has no drawings
# sheet5.xml has 3 images
# sheet6.xml has 26 images
# sheet7.xml has 6 images
# sheet8.xml has 10 images
# sheet9.xml has 54 images
# sheet10.xml has no drawings
# sheet11.xml has no drawings
# sheet12.xml has no drawings
# sheet13.xml has no drawings
# sheet14.xml has no drawings
# sheet15.xml has no drawings
# sheet16.xml has no images
# sheet17.xml has no drawings
# sheet18.xml has no drawings
# sheet19.xml has no drawings
# sheet20.xml has no drawings
# sheet21.xml has no drawings
# sheet22.xml has no drawings
# {'sheet_code_name': 'Sheet5', 'id_': 'rId1', 'row': '7', 'col': '1', 'file_name': 'image1.jpeg'}
# {'sheet_code_name': 'Sheet5', 'id_': 'rId2', 'row': '39', 'col': '1', 'file_name': 'image2.jpeg'}
# {'sheet_code_name': 'Sheet5', 'id_': 'rId3', 'row': '71', 'col': '1', 'file_name': 'image3.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId1', 'row': '9', 'col': '3', 'file_name': 'image4.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId2', 'row': '9', 'col': '41', 'file_name': 'image5.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId3', 'row': '22', 'col': '3', 'file_name': 'image6.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId4', 'row': '22', 'col': '41', 'file_name': 'image7.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId5', 'row': '37', 'col': '3', 'file_name': 'image8.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId6', 'row': '37', 'col': '41', 'file_name': 'image9.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId7', 'row': '50', 'col': '3', 'file_name': 'image10.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId8', 'row': '50', 'col': '41', 'file_name': 'image11.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId9', 'row': '65', 'col': '3', 'file_name': 'image12.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId10', 'row': '65', 'col': '41', 'file_name': 'image13.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId11', 'row': '78', 'col': '3', 'file_name': 'image14.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId12', 'row': '78', 'col': '41', 'file_name': 'image15.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId13', 'row': '93', 'col': '3', 'file_name': 'image16.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId14', 'row': '93', 'col': '41', 'file_name': 'image17.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId15', 'row': '106', 'col': '3', 'file_name': 'image18.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId16', 'row': '121', 'col': '3', 'file_name': 'image19.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId17', 'row': '121', 'col': '41', 'file_name': 'image20.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId18', 'row': '134', 'col': '3', 'file_name': 'image21.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId19', 'row': '134', 'col': '41', 'file_name': 'image22.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId20', 'row': '149', 'col': '3', 'file_name': 'image23.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId21', 'row': '177', 'col': '3', 'file_name': 'image24.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId22', 'row': '177', 'col': '41', 'file_name': 'image25.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId23', 'row': '190', 'col': '3', 'file_name': 'image26.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId24', 'row': '190', 'col': '41', 'file_name': 'image27.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId25', 'row': '205', 'col': '3', 'file_name': 'image28.jpeg'}
# {'sheet_code_name': 'Sheet6', 'id_': 'rId26', 'row': '205', 'col': '41', 'file_name': 'image29.jpeg'}
# {'sheet_code_name': 'Sheet7', 'id_': 'rId1', 'row': '39', 'col': '1', 'file_name': 'image30.jpeg'}
# {'sheet_code_name': 'Sheet7', 'id_': 'rId2', 'row': '103', 'col': '1', 'file_name': 'image31.jpeg'}
# {'sheet_code_name': 'Sheet7', 'id_': 'rId3', 'row': '167', 'col': '1', 'file_name': 'image32.jpeg'}
# {'sheet_code_name': 'Sheet7', 'id_': 'rId4', 'row': '7', 'col': '1', 'file_name': 'image33.jpeg'}
# {'sheet_code_name': 'Sheet7', 'id_': 'rId5', 'row': '71', 'col': '1', 'file_name': 'image34.jpeg'}
# {'sheet_code_name': 'Sheet7', 'id_': 'rId6', 'row': '135', 'col': '1', 'file_name': 'image35.jpeg'}
# {'sheet_code_name': 'Sheet8', 'id_': 'rId1', 'row': '72', 'col': '1', 'file_name': 'image36.jpeg'}
# {'sheet_code_name': 'Sheet8', 'id_': 'rId2', 'row': '104', 'col': '1', 'file_name': 'image37.jpeg'}
# {'sheet_code_name': 'Sheet8', 'id_': 'rId3', 'row': '200', 'col': '1', 'file_name': 'image38.jpeg'}
# {'sheet_code_name': 'Sheet8', 'id_': 'rId4', 'row': '296', 'col': '1', 'file_name': 'image39.jpeg'}
# {'sheet_code_name': 'Sheet8', 'id_': 'rId5', 'row': '8', 'col': '1', 'file_name': 'image40.jpeg'}
# {'sheet_code_name': 'Sheet8', 'id_': 'rId6', 'row': '40', 'col': '1', 'file_name': 'image41.jpeg'}
# {'sheet_code_name': 'Sheet8', 'id_': 'rId7', 'row': '136', 'col': '1', 'file_name': 'image42.jpeg'}
# {'sheet_code_name': 'Sheet8', 'id_': 'rId8', 'row': '168', 'col': '1', 'file_name': 'image43.jpeg'}
# {'sheet_code_name': 'Sheet8', 'id_': 'rId9', 'row': '232', 'col': '1', 'file_name': 'image44.jpeg'}
# {'sheet_code_name': 'Sheet8', 'id_': 'rId10', 'row': '264', 'col': '1', 'file_name': 'image45.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId1', 'row': '9', 'col': '3', 'file_name': 'image46.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId2', 'row': '9', 'col': '41', 'file_name': 'image47.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId3', 'row': '22', 'col': '3', 'file_name': 'image48.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId4', 'row': '22', 'col': '41', 'file_name': 'image49.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId5', 'row': '37', 'col': '3', 'file_name': 'image50.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId6', 'row': '37', 'col': '41', 'file_name': 'image51.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId7', 'row': '50', 'col': '3', 'file_name': 'image52.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId8', 'row': '50', 'col': '41', 'file_name': 'image53.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId9', 'row': '65', 'col': '3', 'file_name': 'image54.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId10', 'row': '65', 'col': '41', 'file_name': 'image55.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId11', 'row': '78', 'col': '3', 'file_name': 'image56.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId12', 'row': '78', 'col': '41', 'file_name': 'image57.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId13', 'row': '93', 'col': '3', 'file_name': 'image58.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId14', 'row': '93', 'col': '41', 'file_name': 'image59.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId15', 'row': '106', 'col': '3', 'file_name': 'image60.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId16', 'row': '106', 'col': '41', 'file_name': 'image11.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId17', 'row': '121', 'col': '3', 'file_name': 'image61.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId18', 'row': '121', 'col': '41', 'file_name': 'image62.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId19', 'row': '134', 'col': '3', 'file_name': 'image63.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId20', 'row': '134', 'col': '41', 'file_name': 'image64.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId21', 'row': '149', 'col': '3', 'file_name': 'image65.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId22', 'row': '149', 'col': '41', 'file_name': 'image66.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId23', 'row': '162', 'col': '3', 'file_name': 'image67.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId24', 'row': '162', 'col': '41', 'file_name': 'image68.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId25', 'row': '177', 'col': '3', 'file_name': 'image69.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId26', 'row': '177', 'col': '41', 'file_name': 'image70.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId27', 'row': '190', 'col': '3', 'file_name': 'image71.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId28', 'row': '190', 'col': '41', 'file_name': 'image72.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId29', 'row': '205', 'col': '3', 'file_name': 'image73.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId30', 'row': '205', 'col': '41', 'file_name': 'image74.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId31', 'row': '218', 'col': '3', 'file_name': 'image75.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId32', 'row': '218', 'col': '41', 'file_name': 'image76.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId33', 'row': '233', 'col': '3', 'file_name': 'image77.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId34', 'row': '233', 'col': '41', 'file_name': 'image78.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId35', 'row': '246', 'col': '3', 'file_name': 'image79.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId36', 'row': '246', 'col': '41', 'file_name': 'image80.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId37', 'row': '261', 'col': '3', 'file_name': 'image81.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId38', 'row': '261', 'col': '41', 'file_name': 'image82.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId39', 'row': '274', 'col': '3', 'file_name': 'image83.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId40', 'row': '274', 'col': '41', 'file_name': 'image84.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId41', 'row': '289', 'col': '3', 'file_name': 'image85.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId42', 'row': '289', 'col': '41', 'file_name': 'image86.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId43', 'row': '302', 'col': '3', 'file_name': 'image87.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId44', 'row': '302', 'col': '41', 'file_name': 'image88.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId45', 'row': '317', 'col': '3', 'file_name': 'image89.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId46', 'row': '317', 'col': '41', 'file_name': 'image90.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId47', 'row': '330', 'col': '3', 'file_name': 'image91.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId48', 'row': '330', 'col': '41', 'file_name': 'image92.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId49', 'row': '345', 'col': '3', 'file_name': 'image93.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId50', 'row': '345', 'col': '41', 'file_name': 'image94.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId51', 'row': '358', 'col': '3', 'file_name': 'image95.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId52', 'row': '358', 'col': '41', 'file_name': 'image96.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId53', 'row': '373', 'col': '3', 'file_name': 'image97.jpeg'}
# {'sheet_code_name': 'Sheet9', 'id_': 'rId54', 'row': '373', 'col': '41', 'file_name': 'image98.jpeg'}

# %%
collector.save_images()
